// %% [markdown]
// # Catálogo de Componentes com Mensagens - Implementações

// %% [markdown]
// # Interface ITableProducer compartilhada

// %%
public interface ITableProducer {
  String[] requestAttributes();
  String[][] requestInstances();
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.ITableProducer

// %%
public interface ITableReceptacle {
  public void connect(ITableProducer producer);
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.ITableReceptacle

// %% [markdown]
// # Interface IUpdate compartilhada

// %%
public interface IUpdate {
  public void update();
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IUpdate

// %%
public interface IUpdateReceptacle {
  public void connect(IUpdate notify);
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IUpdateReceptacle

// %% [markdown]
// # Console

// %%
public interface IConsole extends ITableReceptacle, IUpdate {
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IConsole

// %%
public class ConsoleComponent implements IConsole {
  private ITableProducer iProducer;
  
  public void connect(ITableProducer producer) {
    iProducer = producer;
  }
  
  public void update() {
    if (iProducer != null) {
        System.out.println("=== Attributes ===");
        String attributes[] = iProducer.requestAttributes();
        for (int a = 0; a < attributes.length-1; a++)
          System.out.print(attributes[a] + ", ");
        System.out.println(attributes[attributes.length-1]);

        System.out.println();
        System.out.println("=== Instances ===");
        String instances[][] = iProducer.requestInstances();
        for (int i = 0; i < instances.length; i++) {
          for (int a = 0; a < attributes.length-1; a ++)
            System.out.print(instances[i][a] + ", ");
          System.out.println(instances[i][attributes.length-1]);
        }
    }
  }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.ConsoleComponent

// %% [markdown]
// # BusConsumer

// %%
public interface IBusProperties {
  public String getBusURI();
  public void setBusURI(String dataSource);
  public String getTopic();
  public void setTopic(String topic);
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IBusProperties

// %%
public interface IBusConsumerProperties extends IBusProperties {
  public int getBlockSize();
  public void setBlockSize(int blockSize);
  public int getVerbose();
  public void setVerbose(int verbose);
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IBusConsumerProperties

// %%
public interface IBusConsumer extends ITableProducer, IBusConsumerProperties, IUpdateReceptacle {
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IBusConsumer

// %%
import java.util.Date;

public class SensorReading {
   private Date timestamp;
   private String dimension;
   private double value;
   private String unity;
   
   public SensorReading() {
      /* nothing */
   }
   
   public SensorReading(Date timestamp, String dimension, double value, String unity) {
      this.timestamp = timestamp;
      this.dimension = dimension;
      this.value = value;
      this.unity = unity;
   }

   public Date getTimestamp() {
      return timestamp;
   }
   
   public void setTimestamp(Date timestamp) {
      this.timestamp = timestamp;
   }
   
   public String getDimension() {
      return dimension;
   }
   
   public void setDimension(String dimension) {
      this.dimension = dimension;
   }
   
   public double getValue() {
      return value;
   }
   
   public void setValue(double value) {
      this.value = value;
   }
   
   public String getUnity() {
      return unity;
   }
   
   public void setUnity(String unity) {
      this.unity = unity;
   }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.SensorReading

// %%
public class Message {
   private String source;
   private String name;
   private String type;
   private SensorReading body;
   
   public Message() {
      /* nothing */
   }
   
   public Message(String source, String name, String type, SensorReading body) {
      super();
      this.source = source;
      this.name = name;
      this.type = type;
      this.body = body;
   }

   public String getSource() {
      return source;
   }
   
   public void setSource(String source) {
      this.source = source;
   }
   
   public String getName() {
      return name;
   }
   
   public void setName(String name) {
      this.name = name;
   }
   
   public String getType() {
      return type;
   }
   
   public void setType(String type) {
      this.type = type;
   }
   
   public SensorReading getBody() {
      return body;
   }
   
   public void setBody(SensorReading body) {
      this.body = body;
   }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.Message

// %%
%classpath add jar ../../../../src/lib/mqttv3-1.1.2.jar
%classpath add jar ../../../../src/lib/mysql-connector-java-5.1.17-bin.jar
%classpath add jar ../../../../src/lib/genson-1.6.jar

// %%
import java.text.SimpleDateFormat;
import java.util.ArrayList;
import java.util.UUID;

import org.eclipse.paho.client.mqttv3.IMqttDeliveryToken;
import org.eclipse.paho.client.mqttv3.MqttCallback;
import org.eclipse.paho.client.mqttv3.MqttClient;
import org.eclipse.paho.client.mqttv3.MqttConnectOptions;
import org.eclipse.paho.client.mqttv3.MqttException;
import org.eclipse.paho.client.mqttv3.MqttMessage;

import com.owlike.genson.Genson;
import com.owlike.genson.GensonBuilder;

public class BusConsumerComponent implements IBusConsumer, MqttCallback {
  private String busURI = null;
  private String topic = null;
  private int blockSize = 10;
  private int verbose = 2;
  
  private String[] attributes = {"message", "timestamp", "dimension", "value", "unit"};
  private ArrayList<String[]> instArray = new ArrayList<String[]>();
  private IUpdate notify = null;
  private int count = 0;
  
  private Genson genson;

  private MqttClient client;
  private MqttConnectOptions connectionOptions;
  private String clientID;  
  
  public BusConsumerComponent() {
    /* nothing */
  }

  public String getBusURI() {
    return busURI;
  }

  public void setBusURI(String busURI) {
    this.busURI = busURI;
  }
  
  public String getTopic() {
     return topic;
  }
  
  public void setTopic(String topic) {
     this.topic = topic;
     readDS();
  }
  
  public int getBlockSize() {
     return blockSize;
  }
  
  public void setBlockSize(int blockSize) {
     this.blockSize = blockSize;
  }
  
  public int getVerbose() {
     return verbose;
  }
  
  public void setVerbose(int verbose) {
     this.verbose = verbose;
  }
  
  public void connect(IUpdate notify) {
     this.notify = notify;
  }
  
  public String[] requestAttributes() {
    return attributes;
  }
  
  public String[][] requestInstances() {
    String instances[][] = instArray.toArray(new String[0][]);
    instArray = new ArrayList<String[]>();
    return instances;
  }
  
  private void readDS() {
    genson = new GensonBuilder()
      .useDateFormat(new SimpleDateFormat("yyyy-MM-dd"))
      .useIndentation(true)
      .useConstructorWithArguments(false)
      .create();
     
    clientID = UUID.randomUUID().toString();      
    connectionOptions = new MqttConnectOptions();
    connectionOptions.setAutomaticReconnect(true);
    connectionOptions.setCleanSession(true);
    connectionOptions.setConnectionTimeout(20);
     
    try {
      client = new MqttClient(busURI, clientID);
      client.connect(connectionOptions);            
      client.setCallback(this);
      client.subscribe(topic);
      System.out.println("[MQTTConsumer] connected");            
    } catch (MqttException e) {
      e.printStackTrace();
    }
  }
  
  @Override
  public void connectionLost(Throwable cause) {
    System.out.println("[BusConsumerComponent] Connection lost.  Reason: " + cause);
    System.exit(1);
  }

  @Override
  public void messageArrived(String topic, MqttMessage message) throws MqttException {
    Message mess = genson.deserialize(new String(message.getPayload()), Message.class);
    
    SensorReading body = mess.getBody();
    
    count++;
    String reading[] = {Integer.toString(count),
                        Long.toString(body.getTimestamp().getTime()), body.getDimension(),
                        Double.toString(body.getValue()), body.getUnity()}; 
    instArray.add(reading);
    
    switch (verbose) {
       case 1: System.out.println("message: " + count); break;
       case 2: System.out.println("message: " + count);
               System.out.println("topic: " + topic);
               String json = genson.serialize(mess);
               System.out.println(json);
               break;
    }

    if (count == blockSize && notify != null) {
       count = 0;
       notify.update();
    }
  }


  @Override
  public void deliveryComplete(IMqttDeliveryToken token) {
  }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.BusConsumerComponent

// %% [markdown]
// # Conectando BusConsumer
//
// ## Propriedades
// * `verbose` - define se mostrará na tela as mensagens recebidas:
//   * `0` - não mostra
//   * `1` - mostra somente contagem
//   * `2` - mostra contagem e mensagem

// %%
  try {
    IBusConsumer bc = new BusConsumerComponent();
    bc.setBusURI("tcp://localhost:1883");
    bc.setTopic("sensor/+/+");
    bc.setVerbose(0);  // mostra todas as mensagens
  } catch (Exception e) {
    e.printStackTrace();
  }
// Out:
// [MQTTConsumer] connected
// null

// %% [markdown]
// # Conectando com o Console

// %%
// try {
//      IBusConsumer bc = new BusConsumerComponent();
//      bc.setBusURI("tcp://localhost:1883");
//      bc.setTopic("sensor/+/+");
//      bc.setBlockSize(10);
//      bc.setVerbose(0);  // mostra todas as mensagens

//      IConsole console = new ConsoleComponent();
//      console.connect(bc);

//      bc.connect(console);
    
// } catch (Exception e) {
    
//      e.printStackTrace();
    
// }
// Out:
// null

// %% [markdown]
// ## Projeção

// %%
public interface IProjectionProperties {
  String[] getAttributes();
  void setAttributes(String attribute[]);
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IProjectionProperties

// %%
public interface IProjection extends IProjectionProperties, ITableProducer, ITableReceptacle {
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IProjection

// %%
public class ProjectionComponent implements IProjection {
  private ITableProducer provider;
  
  private String attributes[] = null;
  
  public String[] getAttributes() {
    return attributes;
  }

  public void setAttributes(String attributes[]) {
    this.attributes = attributes;
  }
  
  public void connect(ITableProducer provider) {
    this.provider = provider;
  }
  
  public String[] requestAttributes() {
    return attributes;
  }
  
  public String[][] requestInstances() {
    String[][] instances = null;
    
    if (provider != null) {
      String[][] allInstances = provider.requestInstances();
      if (allInstances != null  && attributes != null) {
        instances = new String[allInstances.length][];
        
        // busca a posicao dos atributos selecionados na tabela original
        String[] allAttributes = provider.requestAttributes();
        int attrPos[] = new int[attributes.length];
        for (int as = 0; as < attributes.length; as++) {
          int aa;
          for (aa = 0; aa < allAttributes.length &&
               !attributes[as].equalsIgnoreCase(allAttributes[aa]); aa++)
            /* nothing */;
          if (aa < allAttributes.length)
            attrPos[as] = aa;
          else
            attrPos[as] = -1;
        }
        
        // filtra atributos selecionados
        for (int i = 0; i < allInstances.length; i++) {
          instances[i] = new String[attributes.length];
          for (int as = 0; as < attributes.length; as++)
            if (attrPos[as] > -1)
              instances[i][as] = allInstances[i][attrPos[as]];
        }
      }
    }
    
    return instances;
  }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.ProjectionComponent

// %%
// try {
//     IBusConsumer bc = new BusConsumerComponent();
//     bc.setBusURI("tcp://localhost:1883");
//     bc.setTopic("sensor/+/+");
//     bc.setBlockSize(10);
//     bc.setVerbose(2);  // mostra todas as mensagens

//     IProjection projection = new ProjectionComponent();
//     String[] attributes = {"dimension", "value"};
//     projection.setAttributes(attributes);
//     projection.connect(bc);

//     IConsole console = new ConsoleComponent();
//     console.connect(projection);

//     bc.connect(console);
    
// } catch (Exception e) {
    
//     e.printStackTrace();
    
// }
// Out:
// null

// %% [markdown]
// ## Seleção

// %%
public interface ISelectionProperties {
  String getAttribute();
  void setAttribute(String attributeA);
  public String getOperator();
  public void setOperator(String operator);
  public String getValue();
  public void setValue(String value);
  boolean isNominalComparison();
  void setNominalComparison(boolean nominalComparison);
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.ISelectionProperties

// %%
public interface ISelection extends ISelectionProperties, ITableProducer, ITableReceptacle {
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.ISelection

// %%
import java.util.ArrayList;

public class SelectionComponent implements ISelection {
  private ITableProducer provider;
  
  private String attribute = null,
                 operator = null,
                 value = null;
  private boolean nominalComparison = true;
  
  public String getAttribute() {
    return attribute;
  }

  public void setAttribute(String attribute) {
    this.attribute = attribute;
  }
  
  public String getOperator() {
    return operator;
  }
  
  public void setOperator(String operator) {
    this.operator = operator;
  }
  
  public String getValue() {
    return value;
  }
  
  public void setValue(String value) {
    this.value = value;
  }
  
  public boolean isNominalComparison() {
    return nominalComparison;
  }

  public void setNominalComparison(boolean nominalComparison) {
    this.nominalComparison = nominalComparison;
  }

  public void connect(ITableProducer provider) {
    this.provider = provider;
  }
  
  public String[] requestAttributes() {
    return (provider == null) ? null : provider.requestAttributes();
  }
  
  public String[][] requestInstances() {
    ArrayList<String[]> instances = null;
    
    if (provider != null) {
      String[][] allInstances = provider.requestInstances();
      
      if (allInstances != null) {
        // busca a posicao dos atributos selecionados na tabela original
        String[] allAttributes = provider.requestAttributes();
        int atrPos;
        for (atrPos = 0; atrPos < allAttributes.length &&
             !attribute.equalsIgnoreCase(allAttributes[atrPos]); atrPos++)
          /* nothing */;
        if (atrPos < allAttributes.length) {
          instances = new ArrayList<String[]>();
          
          for (String[] ai: allInstances) {
            boolean match = false;
            if (nominalComparison) {
              switch (operator.charAt(0)) {
                case '=': if (ai[atrPos].equalsIgnoreCase(value))
                       match = true;
                     break;
                case '<': if (ai[atrPos].compareTo(value) < 0)
                       match = true;
                     break;
                case '>': if (ai[atrPos].compareTo(value) > 0)
                       match = true;
                     break;
                case '!': if (!ai[atrPos].equalsIgnoreCase(value))
                     match = true;
                     break;
              }
            } else {
              switch (operator.charAt(0)) {
                case '=': if (Double.parseDouble(ai[atrPos]) == Double.parseDouble(value))
                            match = true;
                          break;
                case '<': if (Double.parseDouble(ai[atrPos]) < Double.parseDouble(value))
                            match = true;
                          break;
                case '>': if (Double.parseDouble(ai[atrPos]) > Double.parseDouble(value))
                            match = true;
                          break;
                case '!': if (Double.parseDouble(ai[atrPos]) != Double.parseDouble(value))
                            match = true;
                          break;
              }
            }
            if (match)
              instances.add(ai);
                
          }
        }
      }
    }
    
    return (instances == null) ? null : instances.toArray(new String[1][]);
  }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.SelectionComponent

// %%
  try {
    IBusConsumer bc = new BusConsumerComponent();
    bc.setBusURI("tcp://localhost:1883");
    bc.setTopic("sensor/+/+");
    bc.setBlockSize(10);
    bc.setVerbose(1);  // mostra todas as mensagens

    ISelection selection = new SelectionComponent();
    selection.connect(bc);
    selection.setAttribute("value");
    selection.setOperator(">");
    selection.setValue("22");
    selection.setNominalComparison(false);

    IConsole console = new ConsoleComponent();
    console.connect(selection);

    bc.connect(console);
  } catch (Exception e) {
    e.printStackTrace();
  }
// Out:
// [MQTTConsumer] connected
// null
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566000000000, umidade, 52.657587059522115, %
// 3, 1566000000000, temperature, 23.6722657798954, °C
// 4, 1566000000000, temperature, 24.080060522473197, °C
// 5, 1566000000000, temperature, 29.996170724286458, °C
// 6, 1566000000000, umidade, 41.19202596077896, %
// 7, 1566000000000, umidade, 55.6189774319484, %
// 8, 1566000000000, temperature, 24.410726744678147, °C
// 9, 1566000000000, temperature, 23.90276851962276, °C
// 10, 1566000000000, umidade, 56.16148755387378, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566000000000, temperature, 29.78284145965803, °C
// 3, 1566000000000, umidade, 42.42785047374089, %
// 5, 1566000000000, umidade, 51.13207439289107, %
// 6, 1566000000000, temperature, 22.76725498445579, °C
// 7, 1566000000000, temperature, 24.58879633226238, °C
// 8, 1566052285760, temperature, 24.54551643828541, °C
// 9, 1566000000000, temperature, 28.578045809385788, °C
// 10, 1566000000000, umidade, 43.60556227611861, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 52.50461444085906, %
// 2, 1566000000000, temperature, 23.528687194598348, °C
// 4, 1566000000000, umidade, 53.992979706395445, %
// 6, 1566000000000, temperature, 28.390849400809714, °C
// 7, 1566000000000, umidade, 44.538908748348, %
// 9, 1566000000000, umidade, 51.59549880777717, %
// 10, 1566000000000, temperature, 22.967690400108665, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 22.95070778970444, °C
// 2, 1566000000000, temperature, 29.115733702833932, °C
// 3, 1566000000000, umidade, 54.76164083553334, %
// 4, 1566000000000, umidade, 50.84012809268766, %
// 5, 1566000000000, temperature, 23.452257019780113, °C
// 6, 1566052292774, temperature, 24.156636903189018, °C
// 8, 1566000000000, umidade, 53.256864447335545, %
// 10, 1566000000000, umidade, 50.57590882990099, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 29.227131350559524, °C
// 2, 1566000000000, temperature, 22.113803917434566, °C
// 3, 1566000000000, umidade, 58.405490366618906, %
// 4, 1566000000000, temperature, 25.30758645074662, °C
// 5, 1566000000000, temperature, 22.141621328065867, °C
// 6, 1566000000000, umidade, 54.807181452134635, %
// 7, 1566000000000, temperature, 29.2470642329142, °C
// 8, 1566000000000, umidade, 58.36230828135909, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 53.32832436609002, %
// 3, 1566052300784, temperature, 23.193952801421965, °C
// 4, 1566000000000, umidade, 46.052447760566025, %
// 5, 1566000000000, temperature, 28.34950765337476, °C
// 6, 1566000000000, temperature, 25.107678648706383, °C
// 7, 1566000000000, umidade, 58.58562518964634, %
// 8, 1566000000000, temperature, 25.192304933825778, °C
// 10, 1566000000000, umidade, 45.64969605773777, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 29.23985980379303, °C
// 2, 1566000000000, umidade, 56.42679549953822, %
// 3, 1566000000000, temperature, 24.245664018188787, °C
// 5, 1566000000000, umidade, 52.04706147848894, %
// 6, 1566000000000, temperature, 24.05430217310166, °C
// 7, 1566000000000, umidade, 43.79227425841494, %
// 8, 1566000000000, temperature, 29.94911806179517, °C
// 9, 1566000000000, temperature, 23.81149501086412, °C
// 10, 1566052307798, temperature, 25.34011281089528, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 57.34723100168843, %
// 2, 1566000000000, temperature, 25.409880741781137, °C
// 4, 1566000000000, umidade, 47.01037210384285, %
// 5, 1566000000000, temperature, 28.049674763871387, °C
// 6, 1566000000000, umidade, 51.294135251605816, %
// 7, 1566000000000, temperature, 25.99851609422373, °C
// 9, 1566000000000, umidade, 50.29554094286092, %
// 10, 1566000000000, temperature, 23.91161674300814, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 46.212528737419746, %
// 2, 1566000000000, temperature, 28.468854896948766, °C
// 4, 1566000000000, umidade, 56.638009659063385, %
// 5, 1566000000000, temperature, 24.748962963905782, °C
// 6, 1566000000000, temperature, 24.18272727099944, °C
// 7, 1566052315810, temperature, 24.48160843878069, °C
// 8, 1566000000000, umidade, 42.42436006222875, %
// 9, 1566000000000, temperature, 29.567399201850897, °C
// 10, 1566000000000, umidade, 53.09932163829757, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566000000000, temperature, 22.15208928199432, °C
// 3, 1566000000000, umidade, 58.511443764707394, %
// 4, 1566000000000, temperature, 24.946416494481923, °C
// 5, 1566000000000, temperature, 29.350394196136072, °C
// 6, 1566000000000, umidade, 44.15743063072733, %
// 7, 1566000000000, temperature, 22.396921996081257, °C
// 8, 1566000000000, umidade, 51.975427523264806, %
// 9, 1566000000000, temperature, 24.9850883592421, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 43.92088693413752, %
// 2, 1566000000000, temperature, 28.00465098235347, °C
// 3, 1566000000000, umidade, 55.61406306906402, %
// 4, 1566000000000, temperature, 22.01695499374875, °C
// 5, 1566052322814, temperature, 24.488848485809168, °C
// 6, 1566000000000, temperature, 23.18901154972124, °C
// 7, 1566000000000, umidade, 54.54835333591681, %
// 8, 1566000000000, temperature, 25.194136356537904, °C
// 9, 1566000000000, temperature, 29.12968327526013, °C
// 10, 1566000000000, umidade, 42.64377666115429, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 25.874809321962132, °C
// 2, 1566000000000, umidade, 50.01542592181733, %
// 3, 1566000000000, temperature, 23.732168912472144, °C
// 4, 1566000000000, temperature, 25.95584582576412, °C
// 5, 1566000000000, temperature, 29.76040353912688, °C
// 6, 1566000000000, umidade, 45.340704737331606, %
// 7, 1566000000000, umidade, 57.76253356729729, %
// 9, 1566000000000, temperature, 23.364009471774327, °C
// 10, 1566000000000, umidade, 53.64138538785881, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566052330825, temperature, 24.82716896770477, °C
// 3, 1566000000000, temperature, 29.31729151375904, °C
// 4, 1566000000000, umidade, 44.684275577884065, %
// 6, 1566000000000, umidade, 53.81615242667866, %
// 8, 1566000000000, temperature, 22.52808109561271, °C
// 9, 1566000000000, umidade, 47.39786426546125, %
// 10, 1566000000000, temperature, 28.483014343105303, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 53.108099623245714, %
// 2, 1566000000000, temperature, 25.04048420732336, °C
// 3, 1566000000000, temperature, 24.948321473351218, °C
// 4, 1566000000000, umidade, 54.044411171328576, %
// 5, 1566000000000, temperature, 23.252926017647276, °C
// 6, 1566000000000, umidade, 43.44210974062132, %
// 7, 1566000000000, temperature, 29.943428823836612, °C
// 8, 1566000000000, temperature, 24.196413527408787, °C
// 9, 1566052337838, temperature, 25.05963796562137, °C
// 10, 1566000000000, umidade, 53.95126895976708, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 24.244272031947993, °C
// 3, 1566000000000, temperature, 28.446914914835254, °C
// 4, 1566000000000, umidade, 53.88741471964629, %
// 5, 1566000000000, umidade, 50.48003383826081, %
// 6, 1566000000000, temperature, 24.751929363684653, °C
// 8, 1566000000000, umidade, 58.397000697453194, %
// 9, 1566000000000, temperature, 24.827875098524423, °C
// 10, 1566000000000, temperature, 28.866891499690983, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 42.16076638504968, %
// 2, 1566000000000, temperature, 25.46011844920857, °C
// 3, 1566000000000, umidade, 50.85077021522286, %
// 4, 1566000000000, temperature, 22.516199513046345, °C
// 6, 1566052345850, temperature, 24.245792109444924, °C
// 7, 1566000000000, umidade, 40.55166154583677, %
// 8, 1566000000000, temperature, 29.279141169305927, °C
// 9, 1566000000000, umidade, 59.55514127394986, %
// 10, 1566000000000, temperature, 22.49118460598318, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 25.232738607572536, °C
// 2, 1566000000000, umidade, 52.07422590261128, %
// 4, 1566000000000, umidade, 43.89749523279797, %
// 5, 1566000000000, temperature, 28.19096496000935, °C
// 6, 1566000000000, temperature, 23.66089229677388, °C
// 7, 1566000000000, umidade, 52.454533844803606, %
// 8, 1566000000000, temperature, 22.5313522660252, °C
// 10, 1566000000000, umidade, 51.7460216323075, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 28.492301196088153, °C
// 2, 1566000000000, umidade, 56.4541146218355, %
// 3, 1566000000000, temperature, 23.151335974256792, °C
// 4, 1566052352857, temperature, 24.437269625552386, °C
// 5, 1566000000000, temperature, 23.653467246354342, °C
// 6, 1566000000000, umidade, 52.66968748782523, %
// 7, 1566000000000, temperature, 24.42869005810086, °C
// 8, 1566000000000, umidade, 40.22519578544629, %
// 9, 1566000000000, temperature, 28.14860983107132, °C
// 10, 1566000000000, temperature, 25.74009001363004, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 51.75677759060378, %
// 2, 1566000000000, temperature, 24.993142000175578, °C
// 3, 1566000000000, temperature, 23.362399752027585, °C
// 4, 1566000000000, umidade, 46.82263153008341, %
// 5, 1566000000000, temperature, 29.354111054900898, °C
// 6, 1566000000000, umidade, 50.66407549032987, %
// 7, 1566000000000, temperature, 25.654872849141427, °C
// 8, 1566000000000, temperature, 24.048354049759595, °C
// 9, 1566000000000, umidade, 55.86706158291442, %
// 10, 1566000000000, temperature, 23.70389091634012, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566052360870, temperature, 25.30876277715018, °C
// 2, 1566000000000, umidade, 48.722253435961896, %
// 3, 1566000000000, temperature, 28.11401074629241, °C
// 4, 1566000000000, temperature, 23.268947965644085, °C
// 5, 1566000000000, umidade, 53.00356731721317, %
// 6, 1566000000000, temperature, 25.235790542372285, °C
// 7, 1566000000000, temperature, 25.796283367533174, °C
// 8, 1566000000000, umidade, 51.19419248286643, %
// 9, 1566000000000, temperature, 29.585971574845388, °C
// 10, 1566000000000, umidade, 57.93932400959208, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 3, 1566000000000, umidade, 53.77629130516291, %
// 4, 1566000000000, temperature, 23.54051855623659, °C
// 5, 1566000000000, umidade, 41.89830531613536, %
// 6, 1566000000000, temperature, 29.678631447987925, °C
// 8, 1566052367880, temperature, 24.90512618258941, °C
// 9, 1566000000000, umidade, 55.92739461298579, %
// 10, 1566000000000, temperature, 25.863225195888266, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566000000000, umidade, 42.71937105108237, %
// 3, 1566000000000, temperature, 28.287267526754487, °C
// 4, 1566000000000, umidade, 57.552145511780765, %
// 5, 1566000000000, temperature, 24.03933640499404, °C
// 7, 1566000000000, umidade, 56.382765030999806, %
// 9, 1566000000000, umidade, 43.40287455552394, %
// 10, 1566000000000, temperature, 28.145985281540217, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 22.12754182897557, °C
// 2, 1566000000000, umidade, 52.47353832745989, %
// 4, 1566000000000, temperature, 22.468991075806915, °C
// 5, 1566052375896, temperature, 23.612413188463897, °C
// 6, 1566000000000, umidade, 43.246063973760535, %
// 7, 1566000000000, temperature, 28.974120670178262, °C
// 8, 1566000000000, umidade, 57.38717644824066, %
// 9, 1566000000000, temperature, 25.81352327540919, °C
// 10, 1566000000000, temperature, 25.54374074895932, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 56.18826676617318, %
// 3, 1566000000000, umidade, 46.89747861041931, %
// 4, 1566000000000, temperature, 28.473962074949952, °C
// 5, 1566000000000, temperature, 23.425199145347342, °C
// 6, 1566000000000, umidade, 52.9290435570481, %
// 9, 1566000000000, umidade, 53.49400912873052, %
// 10, 1566000000000, temperature, 29.34584940483811, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 50.207856410865936, %
// 2, 1566000000000, temperature, 25.307401023156203, °C
// 3, 1566052382901, temperature, 24.969340316673765, °C
// 5, 1566000000000, umidade, 50.291472003864385, %
// 6, 1566000000000, temperature, 22.865449270073128, °C
// 7, 1566000000000, umidade, 41.78471077952559, %
// 8, 1566000000000, temperature, 28.489100597688264, °C
// 10, 1566000000000, umidade, 55.12479813809057, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 24.76981861787541, °C
// 2, 1566000000000, temperature, 25.00378833110139, °C
// 3, 1566000000000, umidade, 48.30566380021888, %
// 4, 1566000000000, temperature, 28.890930456630738, °C
// 5, 1566000000000, umidade, 51.40130545761841, %
// 8, 1566000000000, umidade, 51.92196831037651, %
// 9, 1566000000000, temperature, 22.71378764595516, °C
// 10, 1566052390916, temperature, 23.62988151114172, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 41.91277013251487, %
// 2, 1566000000000, temperature, 28.990387781964404, °C
// 4, 1566000000000, umidade, 54.73241977939036, %
// 6, 1566000000000, temperature, 22.83349100416494, °C
// 7, 1566000000000, umidade, 50.17818440734432, %
// 8, 1566000000000, temperature, 29.9549342127379, °C
// 9, 1566000000000, umidade, 54.37050042133348, %
// 10, 1566000000000, temperature, 24.327343004246433, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 22.764781104266987, °C
// 2, 1566000000000, umidade, 56.780609380134834, %
// 3, 1566000000000, temperature, 22.654615647989928, °C
// 4, 1566000000000, umidade, 42.16024061407144, %
// 5, 1566000000000, temperature, 28.715999581521675, °C
// 7, 1566052397927, temperature, 24.398471331209244, °C
// 8, 1566000000000, umidade, 58.0536003142643, %
// 9, 1566000000000, temperature, 23.9066405768632, °C
// 10, 1566000000000, temperature, 25.295895110058577, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 45.22614476926479, %
// 2, 1566000000000, temperature, 28.870967817894822, °C
// 3, 1566000000000, umidade, 56.83137601671732, %
// 4, 1566000000000, temperature, 24.8795411488548, °C
// 5, 1566000000000, temperature, 22.85543302354836, °C
// 6, 1566000000000, umidade, 56.72038080166008, %
// 7, 1566000000000, temperature, 23.32011075174959, °C
// 8, 1566000000000, temperature, 28.22899461748919, °C
// 9, 1566000000000, umidade, 40.92704731602641, %
// 10, 1566000000000, temperature, 23.234429705315108, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 53.02810671807038, %
// 2, 1566000000000, temperature, 24.429870085136553, °C
// 4, 1566052405940, temperature, 24.508341526350605, °C
// 5, 1566000000000, temperature, 28.869791553535947, °C
// 6, 1566000000000, umidade, 42.054588198033294, %
// 7, 1566000000000, umidade, 59.26922222081475, %
// 8, 1566000000000, temperature, 25.000702712085015, °C
// 10, 1566000000000, umidade, 55.5227245850547, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 22.644024733097336, °C
// 2, 1566000000000, umidade, 45.63322282033693, %
// 3, 1566000000000, temperature, 29.601011591012476, °C
// 5, 1566000000000, umidade, 55.17320969244338, %
// 7, 1566000000000, temperature, 23.655704623839195, °C
// 8, 1566000000000, temperature, 29.65921494141044, °C
// 9, 1566000000000, umidade, 40.73315207977533, %
// 10, 1566000000000, umidade, 59.181037845583674, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566052412951, temperature, 24.32481923451093, °C
// 3, 1566000000000, temperature, 23.570246412230222, °C
// 4, 1566000000000, umidade, 50.78444115886072, %
// 5, 1566000000000, temperature, 22.986191720811316, °C
// 6, 1566000000000, temperature, 28.950159717210106, °C
// 7, 1566000000000, umidade, 54.9590759426852, %
// 8, 1566000000000, temperature, 25.40165377239868, °C
// 9, 1566000000000, umidade, 54.24203375898758, %
// 10, 1566000000000, temperature, 25.061093894336807, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566000000000, temperature, 28.682251878298963, °C
// 3, 1566000000000, umidade, 53.60616919045874, %
// 4, 1566000000000, umidade, 51.04780323024114, %
// 7, 1566000000000, umidade, 54.35864441307997, %
// 8, 1566000000000, temperature, 24.887615650652155, °C
// 9, 1566052420963, temperature, 24.29331252557709, °C
// 10, 1566000000000, temperature, 29.72042808823472, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 54.21311059143316, %
// 2, 1566000000000, temperature, 25.56244331851222, °C
// 3, 1566000000000, umidade, 53.50872587182408, %
// 4, 1566000000000, temperature, 23.03867368096832, °C
// 6, 1566000000000, temperature, 29.3379232688432, °C
// 7, 1566000000000, umidade, 42.18938141321546, %
// 8, 1566000000000, umidade, 55.88327819899136, %
// 9, 1566000000000, temperature, 25.589517233650028, °C
// 10, 1566000000000, temperature, 22.411026327750506, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 53.65372875369517, %
// 3, 1566000000000, temperature, 29.22046482715655, °C
// 4, 1566000000000, umidade, 43.65586265952065, %
// 5, 1566000000000, temperature, 24.22740039530654, °C
// 6, 1566052427974, temperature, 25.07865810622563, °C
// 7, 1566000000000, umidade, 55.68830264631475, %
// 8, 1566000000000, temperature, 24.87065419965354, °C
// 9, 1566000000000, temperature, 23.194330041926715, °C
// 10, 1566000000000, temperature, 29.3753948303182, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 50.62998935418173, %
// 2, 1566000000000, umidade, 59.651518569409035, %
// 3, 1566000000000, temperature, 22.42483097716842, °C
// 4, 1566000000000, temperature, 23.119603267832712, °C
// 5, 1566000000000, umidade, 56.50262918846935, %
// 6, 1566000000000, temperature, 24.885282981039225, °C
// 7, 1566000000000, temperature, 28.254425365154773, °C
// 8, 1566000000000, umidade, 48.80396313304696, %
// 9, 1566000000000, temperature, 23.34748062114167, °C
// 10, 1566000000000, umidade, 54.17508966068319, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 25.545105679162987, °C
// 2, 1566000000000, temperature, 23.432597317516095, °C
// 3, 1566052435982, temperature, 24.844970528091437, °C
// 4, 1566000000000, temperature, 28.705744288212305, °C
// 5, 1566000000000, umidade, 49.25691743438134, %
// 6, 1566000000000, umidade, 57.44914363181286, %
// 7, 1566000000000, temperature, 24.562026650226905, °C
// 8, 1566000000000, temperature, 25.393074338501457, °C
// 9, 1566000000000, umidade, 55.29590071295567, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 29.622986492264047, °C
// 2, 1566000000000, umidade, 53.29372608129253, %
// 3, 1566000000000, temperature, 23.628324294909795, °C
// 4, 1566000000000, umidade, 55.2591589894028, %
// 6, 1566000000000, temperature, 23.678118386275088, °C
// 7, 1566000000000, temperature, 28.050673419330316, °C
// 8, 1566000000000, umidade, 42.48463478086288, %
// 9, 1566000000000, umidade, 56.89028000322341, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566052442998, temperature, 24.611467559690745, °C
// 3, 1566000000000, umidade, 54.350056107970424, %
// 4, 1566000000000, temperature, 22.016421073957027, °C
// 5, 1566000000000, temperature, 28.375703512171647, °C
// 6, 1566000000000, umidade, 43.76459471516435, %
// 8, 1566000000000, umidade, 53.53739468133122, %
// 9, 1566000000000, temperature, 24.031166879461917, °C
// 10, 1566000000000, temperature, 24.074350514309835, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 29.32374697506259, °C
// 2, 1566000000000, umidade, 50.74039769662046, %
// 3, 1566000000000, umidade, 52.538037271168385, %
// 4, 1566000000000, temperature, 23.882650154906493, °C
// 5, 1566000000000, temperature, 23.86101182712402, °C
// 6, 1566000000000, umidade, 50.72342649563222, %
// 7, 1566000000000, temperature, 23.21992714442862, °C
// 8, 1566052451008, temperature, 24.22606852758829, °C
// 9, 1566000000000, temperature, 29.471404742149232, °C
// 10, 1566000000000, umidade, 40.29264344326485, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566000000000, umidade, 51.81326026469919, %
// 5, 1566000000000, temperature, 29.95065913661283, °C
// 6, 1566000000000, umidade, 50.26512316092044, %
// 7, 1566000000000, umidade, 53.94258268395701, %
// 8, 1566000000000, temperature, 24.494204818763706, °C
// 10, 1566000000000, umidade, 57.69382589705413, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566000000000, temperature, 29.751036485020883, °C
// 3, 1566000000000, umidade, 45.61196727989563, %
// 4, 1566000000000, temperature, 24.70251575700296, °C
// 5, 1566052458016, temperature, 24.608928422406446, °C
// 6, 1566000000000, umidade, 56.46658544087815, %
// 7, 1566000000000, temperature, 24.217948689958895, °C
// 8, 1566000000000, temperature, 23.748781012433337, °C
// 9, 1566000000000, temperature, 29.450760084862125, °C
// 10, 1566000000000, umidade, 46.34567970624855, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 57.92299181273854, %
// 2, 1566000000000, temperature, 25.57580287455785, °C
// 4, 1566000000000, umidade, 55.47200663413267, %
// 6, 1566000000000, temperature, 28.25479386193211, °C
// 7, 1566000000000, umidade, 41.492561346084734, %
// 8, 1566000000000, temperature, 25.049296563771204, °C
// 9, 1566000000000, umidade, 51.272773237100225, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 2, 1566052466031, temperature, 24.003579732486465, °C
// 3, 1566000000000, temperature, 28.94287223337957, °C
// 4, 1566000000000, umidade, 51.47601548208521, %
// 5, 1566000000000, umidade, 53.13883769638608, %
// 7, 1566000000000, temperature, 24.190732984083432, °C
// 8, 1566000000000, umidade, 50.46037133644063, %
// 9, 1566000000000, temperature, 25.313942519937985, °C
// 10, 1566000000000, temperature, 29.532158122531683, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 51.75706806048104, %
// 2, 1566000000000, temperature, 22.959160082437133, °C
// 3, 1566000000000, umidade, 55.55933045950796, %
// 4, 1566000000000, temperature, 22.19936388305954, °C
// 5, 1566000000000, temperature, 24.029933560503736, °C
// 6, 1566000000000, temperature, 28.194374140946312, °C
// 7, 1566000000000, umidade, 46.69792973063048, %
// 8, 1566000000000, umidade, 53.55805613076092, %
// 10, 1566052473043, temperature, 24.762766897993977, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 24.45974303155473, °C
// 2, 1566000000000, umidade, 55.04825808400616, %
// 3, 1566000000000, temperature, 25.103699470372817, °C
// 4, 1566000000000, temperature, 29.420917875310582, °C
// 5, 1566000000000, umidade, 53.6866381724702, %
// 7, 1566000000000, umidade, 56.92829894575526, %
// 8, 1566000000000, temperature, 22.505898887042093, °C
// 9, 1566000000000, temperature, 23.612435862713166, °C
// 10, 1566000000000, temperature, 29.96774610291965, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 53.8296769317497, %
// 2, 1566000000000, umidade, 52.89650497971095, %
// 4, 1566000000000, temperature, 23.02954844463384, °C
// 5, 1566000000000, umidade, 51.176487846368595, %
// 6, 1566000000000, temperature, 24.767775576813108, °C
// 7, 1566052481053, temperature, 24.55738138297827, °C
// 8, 1566000000000, temperature, 28.880159788475236, °C
// 9, 1566000000000, umidade, 46.46774993532462, %
// 10, 1566000000000, temperature, 23.329093694947396, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, umidade, 51.55953154493156, %
// 4, 1566000000000, temperature, 29.031241985279895, °C
// 5, 1566000000000, umidade, 45.977255871868174, %
// 6, 1566000000000, umidade, 57.427691244790246, %
// 8, 1566000000000, temperature, 24.267525424440613, °C
// 9, 1566000000000, umidade, 53.39276478834775, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 29.83445292721164, °C
// 2, 1566000000000, umidade, 51.37741579729215, %
// 3, 1566000000000, temperature, 24.54182376194443, °C
// 4, 1566052488062, temperature, 24.22594764538142, °C
// 5, 1566000000000, umidade, 58.4804270579815, %
// 6, 1566000000000, temperature, 24.202177458719593, °C
// 7, 1566000000000, temperature, 24.06071609026468, °C
// 8, 1566000000000, temperature, 29.85894851820395, °C
// 9, 1566000000000, umidade, 45.58418585667667, %
// 10, 1566000000000, umidade, 58.8092710331164, %
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 24.476677104123077, °C
// 3, 1566000000000, umidade, 55.38759905719229, %
// 5, 1566000000000, temperature, 28.963848614768132, °C
// 6, 1566000000000, umidade, 46.90063000312253, %
// 7, 1566000000000, temperature, 25.591467597386007, °C
// 8, 1566000000000, umidade, 58.59923456818878, %
// 9, 1566000000000, temperature, 25.293633540504576, °C
// 10, 1566000000000, temperature, 24.98015222125785, °C
// message: 1
// message: 2
// message: 3
// message: 4
// message: 5
// message: 6
// message: 7
// message: 8
// message: 9
// message: 10
// === Attributes ===
// message, timestamp, dimension, value, unit
//
// === Instances ===
// 1, 1566000000000, temperature, 28.758190534311733, °C
// 2, 1566000000000, umidade, 40.79051243013549, %
// 3, 1566052496077, temperature, 25.00546428901989, °C
// 4, 1566000000000, umidade, 55.5339201793611, %
// 5, 1566000000000, temperature, 24.69781758594524, °C
// 6, 1566000000000, temperature, 23.06075372514862, °C
// 7, 1566000000000, umidade, 54.28701118610801, %
// 8, 1566000000000, temperature, 22.514763235740578, °C
// 9, 1566000000000, temperature, 28.57952774724456, °C
// 10, 1566000000000, umidade, 54.03407565076611, %
// message: 1
// message: 2
// message: 3

// %% [markdown]
// # Producer Component - Média

// %%
public interface IBusProducerProperties extends IBusProperties {
  public int getVerbose();
  public void setVerbose(int verbose);
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IBusProducerProperties

// %%
public interface IBusProducer extends ITableReceptacle, IBusProducerProperties, IUpdate {
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IBusProducer

// %%
import java.text.SimpleDateFormat;
import java.util.Calendar;
import java.util.UUID;

import org.eclipse.paho.client.mqttv3.IMqttDeliveryToken;
import org.eclipse.paho.client.mqttv3.MqttCallback;
import org.eclipse.paho.client.mqttv3.MqttClient;
import org.eclipse.paho.client.mqttv3.MqttConnectOptions;
import org.eclipse.paho.client.mqttv3.MqttException;
import org.eclipse.paho.client.mqttv3.MqttMessage;

import com.owlike.genson.Genson;
import com.owlike.genson.GensonBuilder;

public class BusProducerComponent implements IBusProducer, MqttCallback {
  private String busURI = null;
  private String topic = null;
  private int verbose = 2;
  
  private int count = 0;
  
  private ITableProducer iProducer;
  
  private Genson genson;

  private MqttClient client;
  private MqttConnectOptions connectionOptions;
  private String clientID;
  private final int qos = 1; 
  
  public BusProducerComponent() {
     genson = new GensonBuilder()
           .useDateFormat(new SimpleDateFormat("yyyy-MM-dd"))
           .useIndentation(true)
           .useConstructorWithArguments(false)
           .create();
  }

  public String getBusURI() {
    return busURI;
  }

  public void setBusURI(String busURI) {
    this.busURI = busURI;
    clientID = UUID.randomUUID().toString();      
    connectionOptions = new MqttConnectOptions();
    connectionOptions.setAutomaticReconnect(true);
    connectionOptions.setCleanSession(true);
    connectionOptions.setConnectionTimeout(20);
     
    try {
      client = new MqttClient(busURI, clientID);
      client.connect(connectionOptions);            
      client.setCallback(this);
      System.out.println("[MQTTProducer] connected");            
    } catch (MqttException e) {
      e.printStackTrace();
    }
  }
  
  public String getTopic() {
     return topic;
  }
  
  public void setTopic(String topic) {
     this.topic = topic;
  }
  
  public int getVerbose() {
     return verbose;
  }
  
  public void setVerbose(int verbose) {
     this.verbose = verbose;
  }
  
  public void connect(ITableProducer producer) {
     iProducer = producer;
  }
   
  public void update() {
     if (iProducer != null) {
        String instances[][] = iProducer.requestInstances();
        double av = 0;
        for (int i = 0; i < instances.length; i++)
           av += Double.parseDouble(instances[i][3]);
        av = (av == 0) ? 0 : av / instances.length;
        
        Message mess = new Message("statistics", "average", "calculus",
              new SensorReading(Calendar.getInstance().getTime(), "temperature", av, instances[0][4])
        );
        String json = genson.serialize(mess);
        MqttMessage message = new MqttMessage(json.getBytes());
        message.setQos(qos);
        
         try {
            client.publish(topic, message);
          } catch (MqttException e) {
            e.printStackTrace();
          }
        count++;
        switch (verbose) {
        case 1: System.out.println("message: " + count); break;
        case 2: System.out.println("message: " + count);
                System.out.println(json);
                break;
        }        
     }
   }
  
  @Override
  public void connectionLost(Throwable cause) {
    System.out.println("[BusProducerComponent] Connection lost.  Reason: " + cause);
    System.exit(1);
  }

  @Override
  public void messageArrived(String topic, MqttMessage message) throws MqttException {
  }

  @Override
  public void deliveryComplete(IMqttDeliveryToken token) {
  }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.BusProducerComponent

// %% [markdown]
// # Publicando a Média

// %%
  try {
     IBusConsumer bc1 = new BusConsumerComponent();
     bc1.setBusURI("tcp://localhost:1883");
     bc1.setTopic("sensor/+/temperature");
     bc1.setBlockSize(10);
     bc1.setVerbose(2);  // mostra todas as mensagens

     IBusProducer bp = new BusProducerComponent();
     bp.setBusURI("tcp://localhost:1883");
     bp.setTopic("sensor/avg/temperature_avg");
     bp.connect(bc1);

     bc1.connect(bp);

     IBusConsumer bc2 = new BusConsumerComponent();
     bc2.setBusURI("tcp://localhost:1883");
     bc2.setTopic("sensor/+/temperature_avg");
     bc2.setVerbose(2);  // mostra todas as mensagens
  } catch (Exception e) {
    e.printStackTrace();
  }
// Out:
// [MQTTConsumer] connected
// [MQTTProducer] connected
// [MQTTConsumer] connected
// null
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.6722657798954
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.080060522473197
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.996170724286458
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.410726744678147
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.90276851962276
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.916460315331797
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.78284145965803
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.337819000190187
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.76725498445579
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.58879633226238
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 1
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052285760,
//     "unity":"°C",
//     "value":24.54551643828541
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052285760,
//     "unity":"°C",
//     "value":24.54551643828541
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.578045809385788
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.528687194598348
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.972276102902832
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.204894653944525
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.390849400809714
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.405226957821824
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.967690400108665
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.95070778970444
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.115733702833932
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.452257019780113
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/avg/temperature_avg
// message: 2
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052292774,
//     "unity":"°C",
//     "value":24.156636903189018
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052292774,
//     "unity":"°C",
//     "value":24.156636903189018
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.552831329076756
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.104103342003462
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.227131350559524
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.113803917434566
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.30758645074662
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.141621328065867
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.2470642329142
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.627885930617342
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.892653690667583
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.724846442133742
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052300784,
//     "unity":"°C",
//     "value":23.193952801421965
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 3
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052300784,
//     "unity":"°C",
//     "value":23.193952801421965
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.34950765337476
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.107678648706383
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.192304933825778
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.673460333589492
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.23985980379303
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.245664018188787
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.77773747171363
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.05430217310166
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.94911806179517
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.81149501086412
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052307798,
//     "unity":"°C",
//     "value":25.34011281089528
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 4
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052307798,
//     "unity":"°C",
//     "value":25.34011281089528
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.409880741781137
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.91094519052521
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.049674763871387
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.99851609422373
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.383967858242375
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.91161674300814
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.468854896948766
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.75093786430096
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.748962963905782
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.18272727099944
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052315810,
//     "unity":"°C",
//     "value":24.48160843878069
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 5
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052315810,
//     "unity":"°C",
//     "value":24.48160843878069
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.567399201850897
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.159161156640938
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.15208928199432
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.946416494481923
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.350394196136072
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.396921996081257
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.9850883592421
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.309408195561964
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.00465098235347
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.01695499374875
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052322814,
//     "unity":"°C",
//     "value":24.488848485809168
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 6
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052322814,
//     "unity":"°C",
//     "value":24.488848485809168
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.18901154972124
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.194136356537904
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.12968327526013
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.874809321962132
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.732168912472144
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.95584582576412
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.76040353912688
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.467503158497795
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.364009471774327
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.604118265931028
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052330825,
//     "unity":"°C",
//     "value":24.82716896770477
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 7
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052330825,
//     "unity":"°C",
//     "value":24.82716896770477
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.31729151375904
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.405979655047496
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.480438999121912
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.52808109561271
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.483014343105303
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.04048420732336
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.948321473351218
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.252926017647276
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.943428823836612
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.196413527408787
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052337838,
//     "unity":"°C",
//     "value":25.05963796562137
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 8
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052337838,
//     "unity":"°C",
//     "value":25.05963796562137
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.244272031947993
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.468365688240592
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.446914914835254
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.751929363684653
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.75153263037971
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.827875098524423
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.866891499690983
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.46011844920857
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.516199513046345
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.12382190489071
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052345850,
//     "unity":"°C",
//     "value":24.245792109444924
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 9
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052345850,
//     "unity":"°C",
//     "value":24.245792109444924
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.279141169305927
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.49118460598318
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.232738607572536
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.225591241226667
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.19096496000935
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.66089229677388
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.5313522660252
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.117193938282085
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.492301196088153
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.151335974256792
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052352857,
//     "unity":"°C",
//     "value":24.437269625552382
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 10
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052352857,
//     "unity":"°C",
//     "value":24.437269625552386
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.653467246354342
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.42869005810086
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.14860983107132
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.74009001363004
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.993142000175578
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.362399752027585
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.354111054900898
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.654872849141427
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.048354049759595
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.70389091634012
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 11
// message: 11
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052360870,
//     "unity":"°C",
//     "value":25.30876277715018
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052360870,
//     "unity":"°C",
//     "value":25.30876277715018
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.11401074629241
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.268947965644085
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.235790542372285
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.796283367533174
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.585971574845388
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.955900215997907
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.307971366402395
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.54051855623659
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.678631447987925
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.56723604258186
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 12
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052367880,
//     "unity":"°C",
//     "value":24.905126182589406
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 12
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052367880,
//     "unity":"°C",
//     "value":24.90512618258941
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.863225195888266
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.63172995433388
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.287267526754487
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.03933640499404
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.81929861846636
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.00701328607305
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.145985281540217
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.12754182897557
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.733742711806205
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.468991075806915
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 13
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052375896,
//     "unity":"°C",
//     "value":23.612413188463897
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 13
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052375896,
//     "unity":"°C",
//     "value":23.612413188463897
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.974120670178262
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.81352327540919
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.54374074895932
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.708174020183137
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.473962074949952
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.425199145347342
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.90731779853472
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.194115005181473
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.34584940483811
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.307401023156203
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 14
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052382901,
//     "unity":"°C",
//     "value":24.969340316673765
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 14
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052382901,
//     "unity":"°C",
//     "value":24.969340316673765
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.33561741221812
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.865449270073128
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.489100597688264
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.328985407552175
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.76981861787541
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.00378833110139
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.890930456630738
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.84915731425097
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.052180058071844
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.71378764595516
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 15
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052390916,
//     "unity":"°C",
//     "value":23.629881511141722
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 15
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052390916,
//     "unity":"°C",
//     "value":23.62988151114172
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.990387781964404
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.59588538574429
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.570116897641142
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.83349100416494
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.9549342127379
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.327343004246433
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.764781104266987
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.654615647989928
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.715999581521675
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.57715869181467
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 16
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052397927,
//     "unity":"°C",
//     "value":24.398471331209244
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 16
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052397927,
//     "unity":"°C",
//     "value":24.398471331209244
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.9066405768632
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.295895110058577
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.870967817894822
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.8795411488548
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.85543302354836
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.32011075174959
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.22899461748919
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.234429705315108
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.429870085136553
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.061532426595868
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 17
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052405940,
//     "unity":"°C",
//     "value":24.508341526350605
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 17
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052405940,
//     "unity":"°C",
//     "value":24.508341526350605
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.869791553535947
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.000702712085015
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.038754294942603
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.644024733097336
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.601011591012476
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.058877698414715
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.359887677811862
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.655704623839195
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.65921494141044
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.360222518959674
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 18
// ...
//     "value":21.806983037459545
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.751036485020883
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.70251575700296
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 24
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052458016,
//     "unity":"°C",
//     "value":24.608928422406446
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 24
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052458016,
//     "unity":"°C",
//     "value":24.608928422406446
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.217948689958895
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.748781012433337
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.450760084862125
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.57580287455785
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.701583195766553
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.846616071467015
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.25479386193211
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.049296563771204
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.98181963822659
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.208395331888926
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 25
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052466031,
//     "unity":"°C",
//     "value":24.003579732486465
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 25
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052466031,
//     "unity":"°C",
//     "value":24.003579732486465
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.94287223337957
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.730721261754088
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.190732984083432
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.313942519937985
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.532158122531683
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.959160082437133
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.19936388305954
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.029933560503736
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.194374140946312
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.534410191306332
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 26
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052473043,
//     "unity":"°C",
//     "value":24.762766897993977
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 26
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052473043,
//     "unity":"°C",
//     "value":24.762766897993977
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.45974303155473
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.103699470372817
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.420917875310582
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.922488960934107
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.505898887042093
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.612435862713166
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.96774610291965
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.783559617488628
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.02954844463384
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.767775576813108
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 27
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052481053,
//     "unity":"°C",
//     "value":24.55738138297827
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 27
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052481053,
//     "unity":"°C",
//     "value":24.55738138297827
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.880159788475236
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.329093694947396
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.643922437291963
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.500449580085345
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.031241985279895
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.113010878640225
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.267525424440613
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.117795975497497
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.83445292721164
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.54182376194443
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 28
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052488062,
//     "unity":"°C",
//     "value":24.22594764538142
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 28
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052488062,
//     "unity":"°C",
//     "value":24.22594764538142
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.202177458719593
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.06071609026468
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":29.85894851820395
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.476677104123077
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.02289604958129
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":21.604125695389776
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.963848614768132
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 8
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.591467597386007
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 9
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":25.293633540504576
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 10
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.98015222125785
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 29
// topic: sensor/avg/temperature_avg
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052496077,
//     "unity":"°C",
//     "value":25.00546428901989
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 29
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566052496077,
//     "unity":"°C",
//     "value":25.00546428901989
//   },
//   "name":"average",
//   "source":"statistics",
//   "type":"calculus"
// }
// message: 1
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.758190534311733
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 2
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":24.69781758594524
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 3
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":23.06075372514862
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 4
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":22.514763235740578
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 5
// topic: sensor/3/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":28.57952774724456
//   },
//   "name":"3",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 6
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.513564059695454
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }
// message: 7
// topic: sensor/1/temperature
// {
//   "body":{
//     "dimension":"temperature",
//     "timestamp":1566000000000,
//     "unity":"°C",
//     "value":20.864336076815743
//   },
//   "name":"1",
//   "source":"sensor",
//   "type":"reading"
// }

// %% [markdown]
// ## Chart

// %%
public interface IChartProperties {
    
    String getTitle();
    void setTitle(String title);
    String getXTitle();
    void setXTitle(String title);
    String getYTitle();
    void setYTitle(String title);

}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IChartProperties

// %%
public interface IRun {

    public boolean start();
    public boolean stop();
    
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IRun

// %%
public interface IChart extends ITableReceptacle, IRun, IChartProperties {
    
    /* Component Interfaces Set */

}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IChart

// %%
%classpath add jar ../../../../src/lib/xchart-3.5.2.jar

// %%
import java.util.ArrayList;
import java.util.Hashtable;
import java.util.List;

import java.io.IOException;

import org.knowm.xchart.BubbleChart;
import org.knowm.xchart.BubbleChartBuilder;
import org.knowm.xchart.SwingWrapper;
import org.knowm.xchart.BitmapEncoder;
import org.knowm.xchart.BitmapEncoder.BitmapFormat;

import com.twosigma.beakerx.mimetype.MIMEContainer;
import java.io.File;
import java.nio.file.Files;

public class ChartBubbleComponent implements IChart {
  private BubbleChart chart = null;

  private String title = "Chart";
  private String xTitle = "X",
                 yTitle = "Y";

  private ITableProducer producer = null;
 
  public void connect(ITableProducer producer) {
    this.producer = producer;
  }
  
  public ChartBubbleComponent() {
  }
  
  public String getTitle() {
    return title;
  }
  
  public void setTitle(String title) {
    this.title = title;
  }

  public String getXTitle() {
    return xTitle;
  }
  
  public void setXTitle(String title) {
    xTitle = title;
  }

  public String getYTitle() {
    return title;
  }
  
  public void setYTitle(String title) {
    yTitle = title;
  }

  public boolean start() {
    boolean status = true;
    
    chart = new BubbleChartBuilder().width(600).height(400).title(title).xAxisTitle(xTitle).yAxisTitle(yTitle).build();
    try{
        
        buildChart();         
        BitmapEncoder.saveBitmap(chart, "./chart", BitmapFormat.PNG);
        
        File file = new File("chart.png");
        byte[] data = Files.readAllBytes(file.toPath());
    
        MIMEContainer image = new MIMEContainer(MIMEContainer.MIME.IMAGE_PNG, data);
        display(image);
      }catch(IOException ex){
        status = false;
        System.out.println (ex.toString());      
      }
        
    return status;
  }
  
  public boolean stop() {
    return true;
  }
  
  public double[] toDouble(String[][] instances, int column ) {
    double[] numbers = new double[instances.length];
    for (int i = 0; i < instances.length; i++)
      numbers[i] = Double.parseDouble(instances[i][column]);
    return numbers;
  }

  private void buildChart() {
    if (chart != null && producer != null) {
      String[][] instances = producer.requestInstances();

      if (instances != null) {
        double[] xData = toDouble(instances, 0),
                 yData = toDouble(instances, 1);
        
        String[] categoryData = null;
        if (instances[0].length > 2) {
          categoryData = new String[instances.length];
          for (int c = 0; c < instances.length; c++)
            categoryData[c] = instances[c][2];
        }
        
        double[] bubbleData = null;
        if (instances[0].length > 3)
          bubbleData = toDouble(producer.requestInstances(), 3);
        else {
          bubbleData = new double[instances.length];
          for (int i = 0; i < xData.length; i++)
            bubbleData[i] = 10;
        }
          
        
        if (categoryData == null ||
            xData.length != yData.length || yData.length != bubbleData.length ||
            bubbleData.length != categoryData.length) {
          chart.addSeries(" ", xData, yData, bubbleData);
        } else {
          Hashtable<String,String> hash = new Hashtable<String,String>();
          int outer = 0;
          int size = categoryData.length;
          while (outer < size) {
            if (hash.containsKey(categoryData[outer]))
              outer++;
            else {
              hash.put(categoryData[outer],categoryData[outer]);
              List<Double> xSub = new ArrayList<Double>(),
                           ySub = new ArrayList<Double>(),
                           bubbleSub = new ArrayList<Double>();
              for (int inner = outer; inner < size; inner++)
                if (categoryData[inner].equalsIgnoreCase(categoryData[outer])) {
                  xSub.add(xData[inner]);
                  ySub.add(yData[inner]);
                  bubbleSub.add(bubbleData[inner]);
                }
              chart.addSeries(categoryData[outer], xSub, ySub, bubbleSub);
              outer++;
            }
          }
        }
      }
      
    }
    
  }
  
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.ChartBubbleComponent

// %%
IDataSet dataset = new DataSetComponent();
dataset.setDataSource("../../../../src/db/datasets/zombie/complete/zombie-health-spreadsheet-ml-training.csv");

IProjection projection = new ProjectionComponent();
projection.connect(dataset);
String attributes[] = {"days_recovery", "age"};
projection.setAttributes(attributes);

IChart chart = new ChartBubbleComponent();
chart.setTitle("Zombie Health");
chart.setXTitle("Days Recovery");
chart.setYTitle("Age");
chart.connect(projection);

return chart.start();
// Out:
// cannot find symbol
//   symbol:   class IDataSet
//   location: class com.twosigma.beaker.javash.bkrcefac9af.BeakerWrapperClass1261714175Id6006a3e1adeb4d83a42ce500b79f07bb
//  IDataSet dataset = new DataSetComponen
//  ^       ^
//
// cannot find symbol
//   symbol:   class DataSetComponent
//   location: class com.twosigma.beaker.javash.bkrcefac9af.BeakerWrapperClass1261714175Id6006a3e1adeb4d83a42ce500b79f07bb
//  IDataSet dataset = new DataSetComponent()
//                         ^               ^

// %% [markdown]
// ## Statistics

// %%
public interface IStatisticsProperties {

    int getSize();

    double[] getValueSet();

    void setValueSet(double[] valueSet);

    double getValueSet(int index);

    void setValueSet(int index, double value);

}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IStatisticsProperties

// %%
/**
 * Interface for a Statistics Class that registers a set of numbers
 * and calculates the sum and average of these numbers. 
 * 
 * @author Andre Santanche
 */
public interface IStatisticsServices {
   /**
    * Inserts a value into the set.
    * @param value the value to be inserted into the set
    */
    public void insertValue(double value);

    
    /**
     * Calculates the sum of the values in the set. Returns zero if the set is empty.
     * @return sum of the values in the set
     */
    public double sum();
  
    
    /**
     * Calculates the average of the values in the set. Returns zero if the set is empty.
     * @return average of the values in the set
     */
    public double average();
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IStatisticsServices

// %%
public interface IStatistics extends IStatisticsServices, IStatisticsProperties {

}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IStatistics

// %%
import java.util.Vector;

/**
 * Registers a set of numbers and calculates the sum and average of these numbers.
 * 
 * @author Andre Santanche
 */
public class StatisticsComponent implements IStatistics {
   private Vector<Double> valueSet;
   
   /*
    * Constructor
    **************/

   public StatisticsComponent() {
      super();
      valueSet = new Vector<Double>();
   }
   
   public StatisticsComponent(int capacity) {
      super();
      valueSet = new Vector<Double>(capacity);
   }

   /* Properties
    ************/
   
   public int getSize() {
       return valueSet.size();
   }
   
   public double[] getValueSet() {
      int size = valueSet.size();
      double result[] = new double[size];
      for (int d = 0; d < size; d++)
         result[d] = valueSet.get(d);
      return result;
   }

   public void setValueSet(double[] valueSet) {
      for (int d = 0; d < valueSet.length; d++)
         this.valueSet.add(valueSet[d]);
   }
   
   public double getValueSet(int index) {
        return (index < getSize()) ? valueSet.get(index) : 0;
   }
   
   public void setValueSet(int index, double value) {
        int position = (index < getSize()) ? index : getSize();
        if (position < getSize())
            valueSet.set(index, value);
        else
            valueSet.add(value);
   }

   /*
    * IStatisticsServices Interface
    *******************************/
   
   public void insertValue(double value) {
      valueSet.add(value);
   }

   public double sum() {
      double theSum = 0.0f;
      
      for (double value : valueSet)
         theSum += value;
      
      return theSum;
   }

   public double average() {
      double avg = 0;
      
      if (valueSet.size() > 0)
         avg = sum() / valueSet.size();
      
      return avg;
   }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.StatisticsComponent

// %%
try {
   IStatistics stat = new StatisticsComponent(3);

   System.out.println("inserido valor: " + 50.0f);
   stat.insertValue(50.0f);
   System.out.println("inserido valor: " + 70.0f);
   stat.insertValue(70.0f);
   System.out.println("inserido valor: " + 30.0f);
   stat.insertValue(30.0f);

   System.out.println("-- somatorio: " + stat.sum());
   System.out.println("-- media: " + stat.average());
   System.out.println("-- tamanho: " + stat.getSize());
} catch (Exception e) {
   e.printStackTrace();
}
// Out:
// inserido valor: 50.0
// inserido valor: 70.0
// inserido valor: 30.0
// -- somatorio: 150.0
// -- media: 50.0
// -- tamanho: 3
// null

// %% [markdown]
// ## Statistics Required

// %%
public interface IRun {
    
    public void start();
    
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IRun

// %%
public interface IStatisticsReceptacle{
    
    public void connect(IStatistics provider);
    
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IStatisticsReceptacle

// %%
public interface IClientProperties {
    public int getSize();    
    public void setSize(int size);
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IClientProperties

// %%
public interface IClient extends IStatisticsReceptacle, IClientProperties, IRun {

}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.IClient

// %%
public class ClientComponent implements IClient {
    public final static int STANDARD_SIZE = 5;
   
    private int size;
    private int first, second;
   
    private IStatistics provider = null;
    
    /*
     * Constructor
     *************/
    
    public ClientComponent() {
      super();
      size = STANDARD_SIZE;
      first = 1;
      second = 1;
    }
    
    /*
     * Properties
     */
    
    public int getSize() {
        return size;
    }
    
    public void setSize(int size) {
        this.size = size;
    }
    
    /*
     * IStatisticsReceptacle Interface
     **********************************/
    
    public void connect(IStatistics provider)
    {
        this.provider = provider;
    }
    
    public int next() {
       int returnNumber = first;
       first = second;
       second = returnNumber + first;
       return returnNumber;
    }
    
    public void start()
    {
       for (int f = 1; f <= size; f++) {
          int nextNumber = next();
          System.out.println("produzido: " + nextNumber);
          provider.insertValue(nextNumber);
       }
   
       System.out.println("-- somatorio: " + provider.sum());
       System.out.println("-- media: " + provider.average());
    }
    
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.ClientComponent

// %% [markdown]
// # Exercícios

// %% [markdown]
// ## Exercício 1

// %% [markdown]
// Conecte os componentes que você achar necessário para mostrar no console o nome e a idade de zumbis com infecção bacteriana.

// %% [markdown]
// ## Exercício 2

// %% [markdown]
// Considerando que o `ClientComponent` gera uma sequência de Fibonacci e que a propriedade `size` deste componente define quantos elementos haverá nessa sequência, conecte `StatisticsComponent` e o `ClientComponent` para que em conjunto calculem a média dos 10 primeiros termos da sequência de Fibonacci.

// %% [markdown]
// ## Exercício 3

// %% [markdown]
// Escreva um componente que se ligue a um componente que forneça a interface `ITableProducer` e que gere uma saída convertendo a primeira coluna da tabela em um vetor de double. Este componente espera que a primeira coluna seja double.

// %% [markdown]
// ## Exercício 4
//
// Usando o seu componente e o `StatisticsComponent`, escreva um código que calcule a média de idade de zumbis.

// %% [markdown]
// ## Exercício 5

// %% [markdown]
// Construa um componente que, dado um dataset e duas colunas alvo, faça a média dos valores da segunda coluna em relação a cada valor distinto da primeira coluna. Seu componente espera o dataset e duas variáveis do tipo `String` referentes à colunas alvo. A primeira String é referente a uma coluna com valores categóricos do Dataset. A segunda String é referente a uma coluna numérica do dataset. Seu componente deverá fazer, para cada valor distinto da primeira coluna alvo, a média dos valores da segunda coluna alvo.
//
//
// Considere, por exemplo, o csv disponível no caminho `"../../../../src/db/datasets/zombie/complete/zombie-health-spreadsheet-ml-training.csv"`.
// Dadas as Strings `column1 = "diagnostic"` e `column2 = "age"`, seu componente deverá fazer a média das idades associadas a cada um dos diagnósticos.
//
// Este componente deve obrigatoriamente ser feito pela conexão de outros componentes.

// %%
import java.util.Date;

public class SensorReading {
   private Date timestamp;
   private String dimension;
   private double value;
   private String unity;
   
   public Date getTimestamp() {
      return timestamp;
   }
   
   public void setTimestamp(Date timestamp) {
      this.timestamp = timestamp;
   }
   
   public String getDimension() {
      return dimension;
   }
   
   public void setDimension(String dimension) {
      this.dimension = dimension;
   }
   
   public double getValue() {
      return value;
   }
   
   public void setValue(double value) {
      this.value = value;
   }
   
   public String getUnity() {
      return unity;
   }
   
   public void setUnity(String unity) {
      this.unity = unity;
   }
}
// Out:
// com.twosigma.beaker.javash.bkrcefac9af.SensorReading
